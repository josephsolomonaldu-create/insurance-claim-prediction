# %% [markdown]
# # Insurance Claim Prediction Project
#
# This project predicts whether a building will have an insurance claim over the insured period using building characteristics. The workflow demonstrates an end-to-end machine learning pipeline, including:
#
# - Data understanding (Notebook 1)
# - Exploratory data analysis (EDA) with insights (Notebook 2)
# - Data preprocessing and data Modeling and evaluation (Notebook 3)
# - Baseline modeling using Logistic Regression and Random Forest
# - Hyperparameter tuning with GridSearchCV
# - Model evaluation using accuracy, ROC-AUC, and confusion matrices
# - Comparison of model performance with clear interpretation
#
# The project highlights best practices in machine learning, model selection, and result communication, making it suitable for showcasing on GitHub for entry-level data science and machine learning roles.
#
# ## PROBLEM STATEMENT
# The objective of this project is to predict the probability that a building will have at least one insurance claim during the insured period, based on its characteristics
#
# ## 1. Data Understanding
#
# ### Objective
# The goal of this notebook is to understand the structure, content and basic characteristics of the insurance dataset before performing any analysis or modelling

# %% [markdown]
# ## 1.1 Load Libraries
# This section import all required python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.2 Load dataset
# 1. Load raw dataset
# 1. display first and last few rows

# %%
Train_data = pd.read_csv("Train_data.csv")

# %%
Train_data.head() # A look at the first(5)observations of the dataset
# Out:
#   Customer Id  YearOfObservation  Insured_Period  Residential  \
# 0      H14663               2013             1.0            0
# 1       H2037               2015             1.0            0
# 2       H3802               2014             1.0            0
# 3       H3834               2013             1.0            0
# 4       H5053               2014             1.0            0
#
#   Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 0                N               V      V          U               290.0
# 1                V               N      O          R               490.0
# 2                N               V      V          U               595.0
# 3                V               V      V          U              2840.0
# 4                V               N      O          R               680.0
#
#    Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0              1             1960.0               .     1053      0
# ...

# %%
Train_data.tail() # A look at the last (5) observations
# Out:
#      Customer Id  YearOfObservation  Insured_Period  Residential  \
# 7155       H5290               2012        1.000000            1
# 7156       H5926               2013        1.000000            0
# 7157       H6204               2016        0.038251            0
# 7158       H6537               2013        1.000000            0
# 7159       H7470               2014        1.000000            0
#
#      Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 7155                V               V      V          U                 NaN
# 7156                V               V      V          U                 NaN
# 7157                V               V      V          U                 NaN
# 7158                V               V      V          U                 NaN
# 7159                V               V      V          U                 NaN
#
#       Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# ...

# %% [markdown]
# ## 1.3 Data structure
# * Data types
# * shape of the dataset
# * column names

# %%
Train_data.dtypes
# Out:
# Customer Id            object
# YearOfObservation       int64
# Insured_Period        float64
# Residential             int64
# Building_Painted       object
# Building_Fenced        object
# Garden                 object
# Settlement             object
# Building Dimension    float64
# Building_Type           int64
# Date_of_Occupancy     float64
# NumberOfWindows        object
# Geo_Code               object
# Claim                   int64
# dtype: object

# %%
Train_data.shape # shows number of rows and columns
# Out:
# (7160, 14)

# %%
Train_data.columns # shows the varaiables of the columns
# Out:
# Index(['Customer Id', 'YearOfObservation', 'Insured_Period', 'Residential',
#        'Building_Painted', 'Building_Fenced', 'Garden', 'Settlement',
#        'Building Dimension', 'Building_Type', 'Date_of_Occupancy',
#        'NumberOfWindows', 'Geo_Code', 'Claim'],
#       dtype='object')

# %% [markdown]
# ## 1.4 Missing values check
# * Identify missing values
# * Summary of missing data

# %%
Train_data.isnull().sum()# checking for missing values
# Out:
# Customer Id             0
# YearOfObservation       0
# Insured_Period          0
# Residential             0
# Building_Painted        0
# Building_Fenced         0
# Garden                  7
# Settlement              0
# Building Dimension    106
# Building_Type           0
# Date_of_Occupancy     508
# NumberOfWindows         0
# Geo_Code              102
# Claim                   0
# dtype: int64

# %%
Train_data.isnull().sum().sort_values(ascending=False)# contains columns with missing values
# Out:
# Date_of_Occupancy     508
# Building Dimension    106
# Geo_Code              102
# Garden                  7
# Customer Id             0
# YearOfObservation       0
# Insured_Period          0
# Residential             0
# Building_Painted        0
# Building_Fenced         0
# Settlement              0
# Building_Type           0
# NumberOfWindows         0
# Claim                   0
# dtype: int64

# %% [markdown]
# ## 1.5 Target variable identification
# * Define the target variable
# * check target distribution

# %%
Train_data['Claim'].value_counts(normalize=True)# check target distribution
# Out:
# Claim
# 0    0.771788
# 1    0.228212
# Name: proportion, dtype: float64

# %% [markdown]
# ## 1.6 Duplicate Records
# * Check for duplicate rows

# %%
Train_data.duplicated().sum() # No duplicate record found
# Out:
# 0

# %% [markdown]
# ## 1.7 Initial Exploratory Data Analysis(EDA)
# * Drop identifier column

# %%
Train_data = Train_data.drop(columns=['Customer Id'])#we drop "customer id" because it has no analytical value.

# %%
Train_data.head()
# Out:
#    YearOfObservation  Insured_Period  Residential Building_Painted  \
# 0               2013             1.0            0                N
# 1               2015             1.0            0                V
# 2               2014             1.0            0                N
# 3               2013             1.0            0                V
# 4               2014             1.0            0                V
#
#   Building_Fenced Garden Settlement  Building Dimension  Building_Type  \
# 0               V      V          U               290.0              1
# 1               N      O          R               490.0              1
# 2               V      V          U               595.0              1
# 3               V      V          U              2840.0              1
# 4               N      O          R               680.0              1
#
#    Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0             1960.0               .     1053      0
# ...

# %% [markdown]
# ## Conclusion
# This notebook provided an initial understanding of the dataset structure and quality, forming the foundation for exploratory data analysis
